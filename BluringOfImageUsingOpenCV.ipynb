# %% [markdown]
# <a href="https://colab.research.google.com/github/Soham-Bundela/OpenCV/blob/main/BluringOfImageUsingOpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing OpenCV Library

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Performing Bluring using Gaussian Blurring

# %%
import cv2
from matplotlib import pyplot as plt

image_path = '/content/SohamBundela.jpg'
image = cv2.imread(image_path)
resized_image_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(9, 16))
plt.imshow(resized_image_rgb)
plt.title('Original Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1899.5), np.float64(799.5), np.float64(-0.5))

# %%
blurred_image = cv2.GaussianBlur(resized_image, (15, 15), 0)
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title('Blurred Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1899.5), np.float64(799.5), np.float64(-0.5))

# %% [markdown]
# # Performing Bluring using Median Blurring

# %%
blurred_image = cv2.medianBlur(resized_image, 15, 0)
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title('Blurred Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1899.5), np.float64(799.5), np.float64(-0.5))

# %% [markdown]
# # Performing Bluring using Bilateral Blurring

# %%
blurred_image = cv2.GaussianBlur(resized_image, (15, 15), 0)
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title('Blurred Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1899.5), np.float64(799.5), np.float64(-0.5))
